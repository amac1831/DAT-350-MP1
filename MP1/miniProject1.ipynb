# %%
# import libraries

import pandas as pd 

import matplotlib.pyplot as plt

# %%
baseballDF = pd.read_csv("sportsViewingHabits.csv")

baseballDF.head()
# Out:
#   age academic_year               major student_athlete  \
# 0  21        Junior    Exercise Science             Yes
# 1  21        Junior           Chemistry             Yes
# 2  21        Senior  Accounting/Finance             Yes
# 3  21        Junior      Communications             Yes
# 4  21        Senior             Finance             Yes
#
#                          sport                when                   where  \
# 0               Baseball (MLB)    Weekend evenings   In a dorm / apartment
# 1  Basketball (NBA or College)    Weekend evenings     At a friend’s place
# 2               Baseball (MLB)  Weekend afternoons   In a dorm / apartment
# 3    Football (NFL or College)  Weekend afternoons  At the stadium / arena
# 4  Basketball (NBA or College)    Weekend evenings     At a friend’s place
#
#                                     why                   why_time  \
# 0                   I played this sport           Fits my schedule
# ...

# %% [markdown]
# Who?
#
# Should find percentages from each "who" question

# %%
baseballDF["age"].value_counts(normalize=True) * 100
# Out:
# age
# 21     47.058824
# 20     23.529412
# 18     11.764706
# 22     11.764706
# 22+     5.882353
# Name: proportion, dtype: float64

# %%
baseballDF["academic_year"].value_counts(normalize=True) * 100
# Out:
# academic_year
# Junior                  41.176471
# Senior                  29.411765
# Freshman                11.764706
# Sophomore               11.764706
# Graduate or 5th Year     5.882353
# Name: proportion, dtype: float64

# %%
baseballDF["major"].value_counts(normalize=True) * 100
# Out:
# major
# Accounting/Finance         17.647059
# Finance                    17.647059
# Exercise Science           11.764706
# Biology                    11.764706
# Chemistry                   5.882353
# Communications              5.882353
# Economics                   5.882353
# Dual Degree Engineering     5.882353
# Accounting                  5.882353
# Data Analytics/Finance      5.882353
# Marketing                   5.882353
# Name: proportion, dtype: float64

# %% [markdown]
# What?
#
# What percentage of users checked each reply from the what question

# %% [markdown]
# When?
#
# Percentage of each option

# %% [markdown]
# Where?
#
# Percentage of each option

# %% [markdown]
# Why?
#
# Percentage of each option
