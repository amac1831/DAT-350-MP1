# %%
# import libraries

import pandas as pd 

import matplotlib.pyplot as plt

# %%
baseballDF = pd.read_csv("sportsViewingHabits.csv")

baseballDF.head()
# Out:
#                    Timestamp What is your age? What is your academic year?  \
# 0  2026/01/26 3:56:10 PM EST                21                      Junior
# 1  2026/02/01 9:50:22 PM EST                21                      Junior
# 2  2026/02/01 9:50:38 PM EST                21                      Senior
# 3  2026/02/01 9:51:15 PM EST                21                      Junior
# 4  2026/02/01 9:51:19 PM EST                21                      Senior
#
#   Major(Check multiple if applicable) Are you a student-athlete?  \
# 0                    Exercise Science                        Yes
# 1                           Chemistry                        Yes
# 2                  Accounting/Finance                        Yes
# 3                      Communications                        Yes
# 4                             Finance                        Yes
#
#   What sport do you watch most often? When do you most often watch sports?  \
# ...
